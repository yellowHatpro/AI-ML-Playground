# %%
import requests

# %%
r = requests.post(
    "http://localhost:11434/api/generate",
    json={
        "model": "qwen2.5:7b",
        "prompt": "Write one killer tweet about the AI industry",
        "stream": False,
    },
)

# %%
print(r.json().get("response"))
# Out:
# 🚀 The AI revolution is here to stay! From transforming industries to unlocking new possibilities, we're just scratching the surface of what's possible. 🤖 Let's embrace the future together! #AIInnovation #TechTrends
