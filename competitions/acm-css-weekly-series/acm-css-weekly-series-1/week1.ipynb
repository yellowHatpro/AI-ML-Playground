# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 14
plt.rcParams['font.family'] = 'bold'
plt.rcParams['axes.labelweight'] = 'bold'
plt.style.use('seaborn-whitegrid')

# %%
cars_df = pd.read_csv('./train.csv')

# %%
cars_df.head()
# Out:
#    car_ID  symboling           CarName fueltype aspiration doornumber  \
# 0      39          0  honda civic 1300      gas        std        two
# 1       9          1         audi 4000      gas      turbo       four
# 2      38          0      honda accord      gas        std        two
# 3     170          2    toyota starlet      gas        NaN        two
# 4     198         -1         volvo 245      gas        std       four
#
#      carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  hatchback        fwd          front       96.5  ...         110
# 1      sedan        fwd          front      105.8  ...         131
# 2  hatchback        fwd          front       96.5  ...         110
# 3  hatchback        rwd          front       98.4  ...         146
# 4      wagon        rwd          front      104.3  ...         141
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
cars_first_df = cars_df[["CarName","doornumber","carbody","wheelbase","carlength","carwidth","carheight","curbweight","cylindernumber","enginesize","fuelsystem","boreratio","stroke","compressionratio","horsepower","peakrpm","citympg","highwaympg","price"]]
cars_first_df.head()
# Out:
#             CarName doornumber    carbody  wheelbase  carlength  carwidth  \
# 0  honda civic 1300        two  hatchback       96.5      167.5      65.2
# 1         audi 4000       four      sedan      105.8      192.7      71.4
# 2      honda accord        two  hatchback       96.5      167.5      65.2
# 3    toyota starlet        two  hatchback       98.4      176.2      65.6
# 4         volvo 245       four      wagon      104.3      188.8      67.2
#
#    carheight  curbweight cylindernumber  enginesize fuelsystem  boreratio  \
# 0       53.3        2289           four         110       1bbl       3.15
# 1       55.9        3086           five         131       mpfi       3.13
# 2       53.3        2236           four         110       1bbl       3.15
# 3       52.0        2551           four         146       mpfi       3.62
# 4       57.5        3042           four         141       mpfi       3.78
#
# ...

# %%
def printXYCharts(df, x, y):
    sns.lmplot(x=x, y=y, data=df, aspect=2)
    plt.xlabel(x)
    plt.ylabel(y)
    plt.title(f'{x} vs {y}')
    plt.show()

# %%
list_of_attributes = ["wheelbase","carlength","carwidth","carheight","curbweight","enginesize","boreratio","stroke","compressionratio","horsepower","peakrpm","citympg","highwaympg","price"]
for attribute in list_of_attributes:
    printXYCharts(cars_first_df, attribute, "price")
